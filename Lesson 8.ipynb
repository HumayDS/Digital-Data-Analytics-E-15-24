# %%
#Extract packages
import pandas as pd
import numpy as np

# %%
#Extract dataset
df = pd.read_csv('https://raw.githubusercontent.com/HumayDS/A15---24-Reqemsal-data-analitika/refs/heads/main/user_activity_growth_2.csv')

# %%
#date
#new_users
#sessions – number of sessions
#acquisition_channel - the channel through which the customer was acquired
#avg_session_duration – average session duration (minutes)
df.head()
# Out:
#          date acquisition_channel  new_users  active_users  sessions  \
# 0  2025-01-01             organic       37.0            75     140.0
# 1  2025-01-01            paid_ads       14.0            28      53.0
# 2  2025-01-01        social_media       18.0            36      56.0
# 3  2025-01-01            referral       30.0            70      88.0
# 4  2025-01-01               email       12.0            33      53.0
#
#    avg_session_duration
# 0                   8.9
# 1                   7.5
# 2                   6.1
# 3                   7.5
# 4                   3.8

# %%
#Category analysis
df['acquisition_channel'].unique()
# Out:
# array(['organic', 'paid_ads', 'social_media', 'referral', 'email',
#        'socialmedia'], dtype=object)

# %%
#Unify the categories
df['acquisition_channel'] = df['acquisition_channel'].replace({
    'socialmedia': 'social_media'
})

# %%
# Count of columns and rows
df.shape
# Out:
# (2298, 6)

# %%
#Check na's
df.isnull().sum()
# Out:
# date                     0
# acquisition_channel      0
# new_users               22
# active_users             0
# sessions                22
# avg_session_duration     0
# dtype: int64

# %%
#Handle with filling median
df = df.fillna(df.median(numeric_only=True))

# %%
#Delete dublicates
df = df.drop_duplicates()

# %%
#Check types of columns
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2276 entries, 0 to 2275
# Data columns (total 6 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   date                  2276 non-null   object
#  1   acquisition_channel   2276 non-null   object
#  2   new_users             2276 non-null   float64
#  3   active_users          2276 non-null   int64
#  4   sessions              2276 non-null   float64
#  5   avg_session_duration  2276 non-null   float64
# dtypes: float64(3), int64(1), object(2)
# memory usage: 124.5+ KB

# %%
#Convert to time format
df['date'] = pd.to_datetime(df['date'])
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2276 entries, 0 to 2275
# Data columns (total 6 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   date                  2276 non-null   datetime64[ns]
#  1   acquisition_channel   2276 non-null   object
#  2   new_users             2276 non-null   float64
#  3   active_users          2276 non-null   int64
#  4   sessions              2276 non-null   float64
#  5   avg_session_duration  2276 non-null   float64
# dtypes: datetime64[ns](1), float64(3), int64(1), object(1)
# memory usage: 124.5+ KB

# %%
df.describe().T
# Out:
#                        count                           mean  \
# date                    2276  2025-08-16 00:20:14.762741760
# new_users             2276.0                      64.501318
# active_users          2276.0                     179.566344
# sessions              2276.0                     282.848858
# avg_session_duration  2276.0                       6.846485
#
#                                       min                  25%  \
# date                  2025-01-01 00:00:00  2025-04-24 00:00:00
# new_users                          -264.0                20.75
# active_users                        -26.0                 54.0
# sessions                            -42.0                 85.0
# avg_session_duration                  3.5                  5.2
#
#                                       50%                  75%  \
# date                  2025-08-16 00:00:00  2025-12-08 00:00:00
# new_users                            47.0                87.25
# active_users                        128.0                240.0
# sessions                            196.0               370.25
# avg_session_duration                  6.9                  8.5
#
#                                       max         std
# date                  2026-03-31 00:00:00         NaN
# new_users                           500.0   63.877668
# active_users                       1414.0  178.190577
# sessions                           4030.0  300.370738
# avg_session_duration                 10.0    1.881571

# %%
#Let’s look at the start and end periods
start_date = df['date'].min()
end_date = df['date'].max()

print(f'Start Date: {start_date}')
print(f'End Date: {end_date}')
# Out:
# Start Date: 2025-01-01 00:00:00
# End Date: 2026-03-31 00:00:00

# %%
#Create month and year columns
df['month'] =  df['date'].dt.month
df['year'] = df['date'].dt.year

# %%
#Outlier check
num_cols = ['new_users', 'active_users', 'sessions', 'avg_session_duration']
Q1 = df[num_cols].quantile(0.25)
Q3 = df[num_cols].quantile(0.75)
IQR = Q3 - Q1

outlier_mask = (df[num_cols] < (Q1 - 2 * IQR)) | (df[num_cols] > (Q3 + 2 * IQR))

# %%
#Outlier check
outlier_mask.sum()
# Out:
# new_users               80
# active_users            84
# sessions                79
# avg_session_duration     0
# dtype: int64

# %%
df_outliers = df[outlier_mask.any(axis=1)]
df_outliers.head(20)
# Out:
#            date acquisition_channel  new_users  active_users  sessions  \
# 63   2025-01-13            referral       42.0           135    2210.0
# 428  2025-03-27            referral       25.0            53     950.0
# 690  2025-05-19             organic       56.0           182    2460.0
# 1140 2025-08-17             organic       35.0           113    1680.0
# 1148 2025-08-18            referral       29.0            65    1090.0
# 1195 2025-08-28             organic      211.0           551    1007.0
# 1250 2025-09-08             organic      172.0           527     991.0
# 1361 2025-09-30            paid_ads      190.0           651    1064.0
# 1423 2025-10-12            referral      216.0           746     914.0
# 1430 2025-10-14             organic      176.0           588    1110.0
# 1485 2025-10-25             organic      214.0           694    1297.0
# 1523 2025-11-01            referral      292.0           869    1476.0
# 1527 2025-11-02        social_media      245.0           609     788.0
# 1530 2025-11-03             organic      253.0           662     982.0
# 1537 2025-11-04        social_media      357.0           791    1357.0
# 1541 2025-11-05            paid_ads      221.0           631    1156.0
# 1542 2025-11-05        social_media      204.0           701     889.0
# 1546 2025-11-06            paid_ads      228.0           642    1019.0
# 1550 2025-11-07             organic      264.0           595     986.0
# 1555 2025-11-08             organic      326.0           657    1027.0
#
#       avg_session_duration  month  year
# 63                     8.8      1  2025
# 428                    7.0      3  2025
# 690                    5.1      5  2025
# 1140                   4.0      8  2025
# 1148                   7.7      8  2025
# 1195                   9.3      8  2025
# 1250                   8.6      9  2025
# 1361                   8.1      9  2025
# 1423                   5.6     10  2025
# 1430                   7.6     10  2025
# 1485                   8.0     10  2025
# 1523                   8.0     11  2025
# 1527                   9.3     11  2025
# 1530                   7.9     11  2025
# 1537                   7.4     11  2025
# 1541                   6.1     11  2025
# 1542                   3.6     11  2025
# 1546                   6.7     11  2025
# 1550                   3.7     11  2025
# 1555                   7.4     11  2025

# %% [markdown]
# #Rule
# ##Outliers are of two types: Real events (should not be removed) and data errors (should be removed).
# ##Before removing an outlier, you must be able to explain its cause.
# ##If you cannot explain it:
#
# ##either keep it
# ##or flag it separately

# %%
df['is_outlier'] = outlier_mask.any(axis=1)

# %%
df.describe().T
# Out:
#                        count                           mean  \
# date                    2276  2025-08-16 00:20:14.762741760
# new_users             2276.0                      64.501318
# active_users          2276.0                     179.566344
# sessions              2276.0                     282.848858
# avg_session_duration  2276.0                       6.846485
# month                 2276.0                        5.63225
# year                  2276.0                    2025.197715
#
#                                       min                  25%  \
# date                  2025-01-01 00:00:00  2025-04-24 00:00:00
# new_users                          -264.0                20.75
# active_users                        -26.0                 54.0
# sessions                            -42.0                 85.0
# avg_session_duration                  3.5                  5.2
# month                                 1.0                  2.0
# year                               2025.0               2025.0
#
#                                       50%                  75%  \
# date                  2025-08-16 00:00:00  2025-12-08 00:00:00
# new_users                            47.0                87.25
# active_users                        128.0                240.0
# sessions                            196.0               370.25
# avg_session_duration                  6.9                  8.5
# month                                 5.0                  9.0
# year                               2025.0               2025.0
#
#                                       max         std
# date                  2026-03-31 00:00:00         NaN
# new_users                           500.0   63.877668
# active_users                       1414.0  178.190577
# sessions                           4030.0  300.370738
# avg_session_duration                 10.0    1.881571
# month                                12.0    3.595552
# year                               2026.0    0.398364

# %%
#Delete outlier
df_clean = df[~outlier_mask.any(axis=1)]

# %%
#Observing some negative values
df_clean.describe().T
# Out:
#                        count                           mean  \
# date                    2158  2025-08-09 14:25:28.081556992
# new_users             2158.0                       55.57785
# active_users          2158.0                     152.204356
# sessions              2158.0                     236.255792
# avg_session_duration  2158.0                       6.851529
# month                 2158.0                       5.481001
# year                  2158.0                    2025.192771
#
#                                       min                  25%  \
# date                  2025-01-01 00:00:00  2025-04-19 00:00:00
# new_users                          -107.0                 20.0
# active_users                        -26.0                51.25
# sessions                            -42.0                 80.0
# avg_session_duration                  3.5                  5.3
# month                                 1.0                  2.0
# year                               2025.0               2025.0
#
#                                       50%                  75%  \
# date                  2025-08-05 00:00:00  2025-11-29 00:00:00
# new_users                            46.0                 81.0
# active_users                        118.5                218.0
# sessions                            185.5                338.0
# avg_session_duration                  6.8                  8.5
# month                                 5.0                  8.0
# year                               2025.0               2025.0
#
#                                       max         std
# date                  2026-03-31 00:00:00         NaN
# new_users                           218.0   47.361737
# active_users                        601.0  129.089743
# sessions                            937.0  203.629156
# avg_session_duration                 10.0    1.880802
# month                                12.0    3.486428
# year                               2026.0    0.394566

# %%
#Handle with negative values
cols = ['new_users', 'active_users', 'sessions']

df_clean = df_clean[(df_clean[cols] >= 0).all(axis=1)]

# %%
#Analysis by channel
channel_users = df.groupby('acquisition_channel')['active_users'].sum().reset_index()
channel_users = channel_users.sort_values(by='active_users', ascending=False)

#channel_users

# %%
channel_users
# Out:
#   acquisition_channel  active_users
# 1             organic        136853
# 4        social_media         91395
# 2            paid_ads         90903
# 3            referral         45775
# 0               email         43767

# %%
df.head()
# Out:
#         date acquisition_channel  new_users  active_users  sessions  \
# 0 2025-01-01             organic       37.0            75     140.0
# 1 2025-01-01            paid_ads       14.0            28      53.0
# 2 2025-01-01        social_media       18.0            36      56.0
# 3 2025-01-01            referral       30.0            70      88.0
# 4 2025-01-01               email       12.0            33      53.0
#
#    avg_session_duration  month  year  is_outlier
# 0                   8.9      1  2025       False
# 1                   7.5      1  2025       False
# 2                   6.1      1  2025       False
# 3                   7.5      1  2025       False
# 4                   3.8      1  2025       False

# %%
#Daily Active Users (DAU)
#total number of active users for each day, providing a time series view of daily user engagement.
dau = df.groupby('date')['active_users'].sum().reset_index()
dau
# Out:
#           date  active_users
# 0   2025-01-01           242
# 1   2025-01-02           227
# 2   2025-01-03           184
# 3   2025-01-04           307
# 4   2025-01-05           339
# ..         ...           ...
# 450 2026-03-27          1195
# 451 2026-03-28          1263
# 452 2026-03-29          1355
# 453 2026-03-30          1486
# 454 2026-03-31          1116
#
# [455 rows x 2 columns]

# %%
#1. DAU (Daily Active Users trend)
#the day-over-day growth rate of active users, showing how user engagement increases or decreases over time.
dau['growth_rate'] = dau['active_users'].pct_change()

# %%
#On which days are there sharp increases or decreases
dau
# Out:
#           date  active_users  growth_rate
# 0   2025-01-01           242          NaN
# 1   2025-01-02           227    -0.061983
# 2   2025-01-03           184    -0.189427
# 3   2025-01-04           307     0.668478
# 4   2025-01-05           339     0.104235
# ..         ...           ...          ...
# 450 2026-03-27          1195    -0.016461
# 451 2026-03-28          1263     0.056904
# 452 2026-03-29          1355     0.072842
# 453 2026-03-30          1486     0.096679
# 454 2026-03-31          1116    -0.248991
#
# [455 rows x 3 columns]

# %%
#Let’s find the days with the fastest growth
#Let’s look at the 5 days with the highest growth.
dau.sort_values(by='growth_rate', ascending=False).head(5)
# Out:
#           date  active_users  growth_rate
# 304 2025-11-01          1852     0.919171
# 6   2025-01-07           432     0.674419
# 3   2025-01-04           307     0.668478
# 68  2025-03-10           587     0.586486
# 35  2025-02-05           455     0.531987

# %%
#Days to be investigated
#+20% and above growth
high_growth = dau[dau['growth_rate'] > 0.2]

#-20% and below decline
high_drop = dau[dau['growth_rate'] < -0.2]

# %%
high_growth
# Out:
#           date  active_users  growth_rate
# 3   2025-01-04           307     0.668478
# 6   2025-01-07           432     0.674419
# 10  2025-01-11           451     0.281250
# 14  2025-01-15           407     0.267913
# 16  2025-01-17           394     0.304636
# 20  2025-01-21           386     0.349650
# 24  2025-01-25           375     0.530612
# 26  2025-01-27           378     0.251656
# 35  2025-02-05           455     0.531987
# 40  2025-02-10           430     0.207865
# 46  2025-02-16           363     0.226351
# 47  2025-02-17           453     0.247934
# 58  2025-02-28           462     0.471338
# 63  2025-03-05           455     0.311239
# 68  2025-03-10           587     0.586486
# 72  2025-03-14           570     0.241830
# 75  2025-03-17           571     0.277405
# 77  2025-03-19           511     0.213777
# 83  2025-03-25           565     0.212446
# 91  2025-04-02           546     0.263889
# 103 2025-04-14           561     0.260674
# 117 2025-04-28           692     0.346304
# 122 2025-05-03           677     0.202487
# 128 2025-05-09           679     0.290875
# 134 2025-05-15           788     0.340136
# 138 2025-05-19           663     0.232342
# 160 2025-06-10           663     0.236940
# 171 2025-06-21           645     0.238004
# 183 2025-07-03           701     0.283883
# 198 2025-07-18           734     0.296820
# 206 2025-07-26           787     0.347603
# 216 2025-08-05           817     0.266667
# 243 2025-09-01           743     0.331541
# 272 2025-09-30           997     0.308399
# 284 2025-10-12          1114     0.240535
# 304 2025-11-01          1852     0.919171
# 333 2025-11-30          2028     0.272271
# 338 2025-12-05          1830     0.258597
# 368 2026-01-04          1168     0.273719
# 374 2026-01-10          1310     0.304781
# 386 2026-01-22          1212     0.292111
# 389 2026-01-25          1279     0.288016
# 393 2026-01-29          1369     0.300095
# 398 2026-02-03          1401     0.392644
# 422 2026-02-27          1380     0.343720

# %%
#. Sessions per user --- 1 How many sessions does a user have on average
df['sessions_per_user'] = df['sessions'] / df['active_users']
df.head()
# Out:
#         date acquisition_channel  new_users  active_users  sessions  \
# 0 2025-01-01             organic       37.0            75     140.0
# 1 2025-01-01            paid_ads       14.0            28      53.0
# 2 2025-01-01        social_media       18.0            36      56.0
# 3 2025-01-01            referral       30.0            70      88.0
# 4 2025-01-01               email       12.0            33      53.0
#
#    avg_session_duration  month  year  is_outlier  sessions_per_user
# 0                   8.9      1  2025       False           1.866667
# 1                   7.5      1  2025       False           1.892857
# 2                   6.1      1  2025       False           1.555556
# 3                   7.5      1  2025       False           1.257143
# 4                   3.8      1  2025       False           1.606061

# %%
#shows the average number of sessions per user for each acquisition channel, helping evaluate user engagement quality across channels.
channel_sessions_per_user = df.groupby('acquisition_channel')['sessions_per_user'].mean().reset_index()
print(channel_sessions_per_user)
# Out:
#   acquisition_channel  sessions_per_user
# 0               email           1.633745
# 1             organic           1.638165
# 2            paid_ads           1.562504
# 3            referral           1.724086
# 4        social_media           1.569738

# %%
#Total engagement - It shows the total time the user spends on the website.
#This calculates the total engagement time by multiplying the number of sessions by the average session duration for each record.
df['total_time'] = df['sessions'] * df['avg_session_duration']

# %%
df.head()
# Out:
#         date acquisition_channel  new_users  active_users  sessions  \
# 0 2025-01-01             organic       37.0            75     140.0
# 1 2025-01-01            paid_ads       14.0            28      53.0
# 2 2025-01-01        social_media       18.0            36      56.0
# 3 2025-01-01            referral       30.0            70      88.0
# 4 2025-01-01               email       12.0            33      53.0
#
#    avg_session_duration  month  year  is_outlier  sessions_per_user  \
# 0                   8.9      1  2025       False           1.866667
# 1                   7.5      1  2025       False           1.892857
# 2                   6.1      1  2025       False           1.555556
# 3                   7.5      1  2025       False           1.257143
# 4                   3.8      1  2025       False           1.606061
#
#    total_time
# 0      1246.0
# 1       397.5
# 2       341.6
# 3       660.0
# 4       201.4

# %%
#channel's performance
#The worst-performing channel is email.
#The best-performing channel is organic.
channel_perf = df.groupby('acquisition_channel').agg(
    total_time=('total_time', 'sum'),
    count=('date', 'count')
).reset_index()

channel_perf = channel_perf.sort_values(by='total_time', ascending=False)

channel_perf
# Out:
#   acquisition_channel  total_time  count
# 1             organic   1486465.6    449
# 4        social_media    990550.8    469
# 2            paid_ads    947789.8    453
# 3            referral    513911.2    453
# 0               email    467797.6    452

# %%
#The channel that brings the most users is not necessarily the most effective — effectiveness should be measured by user engagement and time spent on the platform
channel_stats = df.groupby('acquisition_channel').agg(
    total_time=('total_time', 'sum'),
    session_count=('sessions', 'sum')
).reset_index()

print(channel_stats)
# Out:
#   acquisition_channel  total_time  session_count
# 0               email    467797.6        68647.0
# 1             organic   1486465.6       217938.0
# 2            paid_ads    947789.8       139709.0
# 3            referral    513911.2        74209.0
# 4        social_media    990550.8       143261.0

# %%
#shows the average number of sessions for each day of the week, helping identify which days have higher or lower user activity.
df['weekday'] = pd.to_datetime(df['date']).dt.day_name()

df.groupby('weekday')['sessions'].mean()
# Out:
# weekday
# Friday       284.603077
# Monday       300.787692
# Saturday     282.609231
# Sunday       284.956923
# Thursday     276.169231
# Tuesday      278.726154
# Wednesday    272.122699
# Name: sessions, dtype: float64

# %%
#Anomaly days
df[df['is_outlier'] == True]
# Out:
#            date acquisition_channel  new_users  active_users  sessions  \
# 63   2025-01-13            referral       42.0           135    2210.0
# 428  2025-03-27            referral       25.0            53     950.0
# 690  2025-05-19             organic       56.0           182    2460.0
# 1140 2025-08-17             organic       35.0           113    1680.0
# 1148 2025-08-18            referral       29.0            65    1090.0
# ...         ...                 ...        ...           ...       ...
# 2215 2026-03-20             organic      227.0           678     967.0
# 2226 2026-03-22            paid_ads      237.0           736     885.0
# 2230 2026-03-23             organic      254.0           780    1313.0
# 2242 2026-03-25        social_media      280.0           918    1242.0
# 2270 2026-03-31             organic      274.0           613     757.0
#
#       avg_session_duration  month  year  is_outlier  sessions_per_user  \
# 63                     8.8      1  2025        True          16.370370
# 428                    7.0      3  2025        True          17.924528
# 690                    5.1      5  2025        True          13.516484
# 1140                   4.0      8  2025        True          14.867257
# 1148                   7.7      8  2025        True          16.769231
# ...                    ...    ...   ...         ...                ...
# 2215                   5.7      3  2026        True           1.426254
# 2226                   5.2      3  2026        True           1.202446
# 2230                   7.1      3  2026        True           1.683333
# 2242                   3.9      3  2026        True           1.352941
# 2270                   5.1      3  2026        True           1.234910
#
#       total_time    weekday
# 63       19448.0     Monday
# 428       6650.0   Thursday
# 690      12546.0     Monday
# 1140      6720.0     Sunday
# 1148      8393.0     Monday
# ...          ...        ...
# 2215      5511.9     Friday
# 2226      4602.0     Sunday
# 2230      9322.3     Monday
# 2242      4843.8  Wednesday
# 2270      3860.7    Tuesday
#
# [118 rows x 12 columns]
